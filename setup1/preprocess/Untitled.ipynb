# %%
import pickle

# %%
with open("spectrograms/sr_24000_mel_norm_128frame_256mel/train_128.pkl", 'rb') as f:
        data = pickle.load(f)

# %%
data
# Out:
# {'arctic_a0001.wav': array([[-0.03459428, -0.5995355 , -1.0893518 , ..., -0.0759009 ,
#          -0.07587206, -0.07587264],
#         [ 0.0362663 ,  0.22020307,  0.21586497, ..., -0.0759009 ,
#          -0.07587206, -0.07587264],
#         [ 0.15632361,  0.41923508,  0.56179357, ..., -0.0759009 ,
#          -0.07587206, -0.07587264],
#         ...,
#         [ 0.03962133,  0.23115662,  0.28845522, ..., -0.0759009 ,
#          -0.07587206, -0.07587264],
#         [-0.5874948 ,  0.08101118,  0.11794408, ..., -0.0759009 ,
#          -0.07587206, -0.07587264],
#         [ 0.8345401 ,  0.90112185,  1.0364273 , ...,  2.2760577 ,
#           2.2486842 ,  2.239281  ]], dtype=float32),
#  'arctic_a0002.wav': array([[-0.2341032 , -0.7082786 , -0.28016376, ...,  0.9178688 ,
#           0.9122089 ,  0.9161111 ],
#         [-0.12316147,  0.18626256,  0.3465303 , ..., -0.0759009 ,
#          -0.07587206, -0.07587264],
#         [-0.02047589,  0.37557855,  0.5367889 , ..., -0.0759009 ,
# ...
