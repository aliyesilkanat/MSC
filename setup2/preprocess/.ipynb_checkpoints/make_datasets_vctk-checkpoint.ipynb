# %%
import pickle 
import librosa 
import sys
import glob 
import random
import os
from collections import defaultdict
import re
import numpy as np
import json
from tacotron.utils import get_spectrograms
import pandas as pd
import gc 

def read_speaker_info(speaker_info_path):
    speaker_ids = []
    with open(speaker_info_path, 'r') as f:
        for i, line in enumerate(f):
            if i == 0:
                continue
            speaker_id = line.strip().split()[0]
            speaker_ids.append(speaker_id)
    return speaker_ids


def wave_feature_extraction(wav_file, sr):
    y, sr = librosa.load(wav_file, sr)
    y, _ = librosa.effects.trim(y, top_db=20)
    return y

def spec_feature_extraction(wav_file):
    mel, mag = get_spectrograms(wav_file)
    return mel, mag


def sample_single_segments(pickle_path,sample_path,segment_size,n_samples):

    with open(pickle_path, 'rb') as f:
        data = pickle.load(f)

    # (utt_id, timestep, neg_utt_id, neg_timestep)
    samples = []

    # filter length > segment_size
    utt_list = [key for key in data]
    utt_list = sorted(list(filter(lambda u : len(data[u]) > segment_size, utt_list)))
    print(f'{len(utt_list)} utterances')
    sample_utt_index_list = random.choices(range(len(utt_list)), k=n_samples)

    for i, utt_ind in enumerate(sample_utt_index_list):
        if i % 500 == 0:
            print(f'sample {i} samples')
        utt_id = utt_list[utt_ind]
        t = random.randint(0, len(data[utt_id]) - segment_size)
        samples.append((utt_id, t))

    with open(sample_path, 'w') as f:
        json.dump(samples, f)

# %%
l1arctic_training_ids=[a[44:47] for a in sorted(glob.glob("/raid/users/ayesilkanat/MSC/L1Arctic/*_arctic"))]
l2arctic_training_ids=['ABA','SKA','BWC','LXC','ASI','SVBI','HKK','HJK','EBVS','MBMPS','HQTV','PNV']
train_speaker_ids = l1arctic_training_ids + l2arctic_training_ids
test_speaker_ids=['YBAA', 'NCC', 'RRBI', 'YDCK', 'ERMS', 'THV']
stage=0
segment_size=128
n_out_speakers=20
test_prop=0.1
sample_rate=24000
training_samples=10000000
testing_samples=10000
n_utt_attr=5000


output_dir = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel"
test_proportion = test_prop

n_utts_attr = n_utt_attr


speaker2filenames = defaultdict(lambda : [])


for tr_id in l1arctic_training_ids:
    for path in sorted(glob.glob("/raid/users/ayesilkanat/MSC/L1Arctic/cmu_us_"+tr_id+"_arctic/wav/*.wav")):
        speaker2filenames[tr_id].append(path)


for tst_id in l2arctic_training_ids:
        
    for path in sorted(glob.glob("/raid/users/ayesilkanat/MSC/ArcticL2/"+tst_id+"/wav/*.wav")):
        speaker2filenames[tst_id].append(path)
      
        
for tst_id in test_speaker_ids:
        
    for path in sorted(glob.glob("/raid/users/ayesilkanat/MSC/ArcticL2/"+tst_id+"/wav/*.wav")):
        speaker2filenames[tst_id].append(path)
        
        
        
train_path_list, in_test_path_list, out_test_path_list = [], [], []
for speaker in train_speaker_ids:
    path_list = speaker2filenames[speaker]
    random.shuffle(path_list)
    test_data_size = int(len(path_list) * test_proportion)
    train_path_list += path_list[:-test_data_size]
    in_test_path_list += path_list[-test_data_size:]
for speaker in test_speaker_ids:
    path_list = speaker2filenames[speaker]
    out_test_path_list += path_list

# %%
speaker2filenames.keys()
# Out:
# dict_keys(['awb', 'bdl', 'clb', 'jmk', 'ksp', 'rms', 'slt', 'ABA', 'SKA', 'BWC', 'LXC', 'ASI', 'SVBI', 'HKK', 'HJK', 'EBVS', 'MBMPS', 'HQTV', 'PNV', 'YBAA', 'NCC', 'RRBI', 'YDCK', 'ERMS', 'THV'])

# %%
with open(os.path.join(output_dir, 'in_test_files.txt'), 'w') as f:
    for path in in_test_path_list:
        f.write(f'{path}\n')



with open(os.path.join(output_dir, 'out_test_files.txt'), 'w') as f:
    for path in out_test_path_list:
        f.write(f'{path}\n')

# %%
for dset, path_list in zip(['train', 'in_test', 'out_test'], \
        [train_path_list, in_test_path_list, out_test_path_list]):
    print(f'processing {dset} set, {len(path_list)} files')
    data = {}
    output_path = os.path.join(output_dir, f'{dset}.pkl')
    all_train_data = []
    for i, path in enumerate(sorted(path_list)):
        if i % 500 == 0 or i == len(path_list) - 1:
            print(f'processing {i} files')
        filename = path.strip().split('/')[-1]
        mel, mag = spec_feature_extraction(path)
        data[filename] = mel
        if dset == 'train' and i < n_utts_attr:
            all_train_data.append(mel)
    if dset == 'train':
        all_train_data = np.concatenate(all_train_data)
        mean = np.mean(all_train_data, axis=0)
        std = np.std(all_train_data, axis=0)
        attr = {'mean': mean, 'std': std}
        with open(os.path.join(output_dir, 'attr.pkl'), 'wb') as f:
            pickle.dump(attr, f)
    for key, val in data.items():
        val = (val - mean) / std
        data[key] = val
    with open(output_path, 'wb') as f:
        pickle.dump(data, f)
# Out:
# processing train set, 19105 files
# processing 0 files
# processing 500 files
# processing 1000 files
# processing 1500 files
# processing 2000 files
# processing 2500 files
# processing 3000 files
# processing 3500 files
# processing 4000 files
# processing 4500 files
# processing 5000 files
# processing 5500 files
# processing 6000 files
# processing 6500 files
# processing 7000 files
# processing 7500 files
# processing 8000 files
# processing 8500 files
# processing 9000 files
# processing 9500 files
# processing 10000 files
# processing 10500 files
# processing 11000 files
# processing 11500 files
# processing 12000 files
# processing 12500 files
# processing 13000 files
# processing 13500 files
# processing 14000 files
# processing 14500 files
# processing 15000 files
# processing 15500 files
# processing 16000 files
# processing 16500 files
# processing 17000 files
# processing 17500 files
# processing 18000 files
# processing 18500 files
# processing 19000 files
# processing 19104 files
# processing in_test set, 2117 files
# processing 0 files
# processing 500 files
# processing 1000 files
# processing 1500 files
# processing 2000 files
# processing 2116 files
# processing out_test set, 6786 files
# processing 0 files
# processing 500 files
# processing 1000 files
# processing 1500 files
# processing 2000 files
# processing 2500 files
# processing 3000 files
# processing 3500 files
# processing 4000 files
# processing 4500 files
# processing 5000 files
# processing 5500 files
# processing 6000 files
# processing 6500 files
# processing 6785 files

# %%
del data
gc.collect()

# %%
# Out:
# 14585

# %%
pkl_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/train.pkl"
output_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/train_"+str(segment_size)+".pkl"

with open(pkl_path, 'rb') as f:
    data = pickle.load(f)

reduced_data = {key:val for key, val in data.items() if val.shape[0] > segment_size}

with open(output_path, 'wb') as f:
    pickle.dump(reduced_data, f)

# %%
del reduced_data
gc.collect()
# Out:
# 495

# %%
pickle_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/train.pkl"
sample_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/train_samples_"+str(segment_size)+".json"
n_samples = training_samples

sample_single_segments(pickle_path,sample_path,segment_size,n_samples)
gc.collect()
# Out:
# 1042 utterances
# sample 0 samples
# sample 500 samples
# sample 1000 samples
# sample 1500 samples
# sample 2000 samples
# sample 2500 samples
# sample 3000 samples
# sample 3500 samples
# sample 4000 samples
# sample 4500 samples
# sample 5000 samples
# sample 5500 samples
# sample 6000 samples
# sample 6500 samples
# sample 7000 samples
# sample 7500 samples
# sample 8000 samples
# sample 8500 samples
# sample 9000 samples
# sample 9500 samples
# sample 10000 samples
# sample 10500 samples
# sample 11000 samples
# sample 11500 samples
# sample 12000 samples
# sample 12500 samples
# sample 13000 samples
# sample 13500 samples
# sample 14000 samples
# sample 14500 samples
# sample 15000 samples
# sample 15500 samples
# sample 16000 samples
# sample 16500 samples
# sample 17000 samples
# sample 17500 samples
# sample 18000 samples
# sample 18500 samples
# sample 19000 samples
# sample 19500 samples
# sample 20000 samples
# sample 20500 samples
# sample 21000 samples
# sample 21500 samples
# sample 22000 samples
# sample 22500 samples
# sample 23000 samples
# sample 23500 samples
# sample 24000 samples
# sample 24500 samples
# sample 25000 samples
# sample 25500 samples
# sample 26000 samples
# sample 26500 samples
# sample 27000 samples
# sample 27500 samples
# sample 28000 samples
# sample 28500 samples
# sample 29000 samples
# sample 29500 samples
# sample 30000 samples
# sample 30500 samples
# sample 31000 samples
# sample 31500 samples
# sample 32000 samples
# sample 32500 samples
# sample 33000 samples
# sample 33500 samples
# sample 34000 samples
# sample 34500 samples
# sample 35000 samples
# sample 35500 samples
# sample 36000 samples
# sample 36500 samples
# sample 37000 samples
# sample 37500 samples
# sample 38000 samples
# sample 38500 samples
# sample 39000 samples
# sample 39500 samples
# sample 40000 samples
# sample 40500 samples
# sample 41000 samples
# sample 41500 samples
# sample 42000 samples
# sample 42500 samples
# sample 43000 samples
# sample 43500 samples
# sample 44000 samples
# sample 44500 samples
# sample 45000 samples
# sample 45500 samples
# sample 46000 samples
# sample 46500 samples
# sample 47000 samples
# sample 47500 samples
# sample 48000 samples
# sample 48500 samples
# sample 49000 samples
# sample 49500 samples
# sample 50000 samples
# sample 50500 samples
# sample 51000 samples
# sample 51500 samples
# sample 52000 samples
# sample 52500 samples
# sample 53000 samples
# sample 53500 samples
# sample 54000 samples
# sample 54500 samples
# sample 55000 samples
# sample 55500 samples
# sample 56000 samples
# sample 56500 samples
# sample 57000 samples
# sample 57500 samples
# sample 58000 samples
# sample 58500 samples
# sample 59000 samples
# sample 59500 samples
# sample 60000 samples
# sample 60500 samples
# sample 61000 samples
# sample 61500 samples
# sample 62000 samples
# sample 62500 samples
# sample 63000 samples
# sample 63500 samples
# sample 64000 samples
# sample 64500 samples
# sample 65000 samples
# sample 65500 samples
# sample 66000 samples
# sample 66500 samples
# sample 67000 samples
# sample 67500 samples
# sample 68000 samples
# sample 68500 samples
# sample 69000 samples
# sample 69500 samples
# sample 70000 samples
# sample 70500 samples
# sample 71000 samples
# sample 71500 samples
# sample 72000 samples
# sample 72500 samples
# sample 73000 samples
# sample 73500 samples
# sample 74000 samples
# sample 74500 samples
# sample 75000 samples
# sample 75500 samples
# sample 76000 samples
# sample 76500 samples
# sample 77000 samples
# sample 77500 samples
# sample 78000 samples
# sample 78500 samples
# sample 79000 samples
# sample 79500 samples
# sample 80000 samples
# sample 80500 samples
# sample 81000 samples
# sample 81500 samples
# sample 82000 samples
# sample 82500 samples
# sample 83000 samples
# sample 83500 samples
# sample 84000 samples
# sample 84500 samples
# sample 85000 samples
# sample 85500 samples
# sample 86000 samples
# sample 86500 samples
# sample 87000 samples
# sample 87500 samples
# sample 88000 samples
# sample 88500 samples
# sample 89000 samples
# sample 89500 samples
# sample 90000 samples
# sample 90500 samples
# sample 91000 samples
# sample 91500 samples
# sample 92000 samples
# sample 92500 samples
# sample 93000 samples
# sample 93500 samples
# sample 94000 samples
# sample 94500 samples
# sample 95000 samples
# sample 95500 samples
# sample 96000 samples
# sample 96500 samples
# sample 97000 samples
# sample 97500 samples
# sample 98000 samples
# sample 98500 samples
# sample 99000 samples
# sample 99500 samples
# sample 100000 samples
# sample 100500 samples
# sample 101000 samples
# sample 101500 samples
# sample 102000 samples
# sample 102500 samples
# sample 103000 samples
# sample 103500 samples
# sample 104000 samples
# sample 104500 samples
# sample 105000 samples
# sample 105500 samples
# sample 106000 samples
# sample 106500 samples
# sample 107000 samples
# sample 107500 samples
# sample 108000 samples
# sample 108500 samples
# sample 109000 samples
# sample 109500 samples
# sample 110000 samples
# sample 110500 samples
# sample 111000 samples
# sample 111500 samples
# sample 112000 samples
# sample 112500 samples
# sample 113000 samples
# sample 113500 samples
# sample 114000 samples
# sample 114500 samples
# sample 115000 samples
# sample 115500 samples
# sample 116000 samples
# sample 116500 samples
# sample 117000 samples
# sample 117500 samples
# sample 118000 samples
# sample 118500 samples
# sample 119000 samples
# sample 119500 samples
# sample 120000 samples
# sample 120500 samples
# sample 121000 samples
# sample 121500 samples
# sample 122000 samples
# sample 122500 samples
# sample 123000 samples
# sample 123500 samples
# sample 124000 samples
# sample 124500 samples
# sample 125000 samples
# sample 125500 samples
# sample 126000 samples
# sample 126500 samples
# sample 127000 samples
# sample 127500 samples
# sample 128000 samples
# sample 128500 samples
# sample 129000 samples
# sample 129500 samples
# sample 130000 samples
# sample 130500 samples
# sample 131000 samples
# sample 131500 samples
# sample 132000 samples
# sample 132500 samples
# sample 133000 samples
# sample 133500 samples
# sample 134000 samples
# sample 134500 samples
# sample 135000 samples
# sample 135500 samples
# sample 136000 samples
# sample 136500 samples
# sample 137000 samples
# sample 137500 samples
# sample 138000 samples
# sample 138500 samples
# sample 139000 samples
# sample 139500 samples
# sample 140000 samples
# sample 140500 samples
# sample 141000 samples
# sample 141500 samples
# sample 142000 samples
# sample 142500 samples
# sample 143000 samples
# sample 143500 samples
# sample 144000 samples
# sample 144500 samples
# sample 145000 samples
# sample 145500 samples
# sample 146000 samples
# sample 146500 samples
# sample 147000 samples
# sample 147500 samples
# sample 148000 samples
# sample 148500 samples
# sample 149000 samples
# sample 149500 samples
# sample 150000 samples
# sample 150500 samples
# sample 151000 samples
# sample 151500 samples
# sample 152000 samples
# sample 152500 samples
# sample 153000 samples
# sample 153500 samples
# sample 154000 samples
# sample 154500 samples
# sample 155000 samples
# sample 155500 samples
# sample 156000 samples
# sample 156500 samples
# sample 157000 samples
# sample 157500 samples
# sample 158000 samples
# sample 158500 samples
# sample 159000 samples
# sample 159500 samples
# sample 160000 samples
# sample 160500 samples
# sample 161000 samples
# sample 161500 samples
# sample 162000 samples
# sample 162500 samples
# sample 163000 samples
# sample 163500 samples
# sample 164000 samples
# sample 164500 samples
# sample 165000 samples
# sample 165500 samples
# sample 166000 samples
# sample 166500 samples
# sample 167000 samples
# sample 167500 samples
# sample 168000 samples
# sample 168500 samples
# sample 169000 samples
# sample 169500 samples
# sample 170000 samples
# sample 170500 samples
# sample 171000 samples
# sample 171500 samples
# sample 172000 samples
# sample 172500 samples
# sample 173000 samples
# sample 173500 samples
# sample 174000 samples
# sample 174500 samples
# sample 175000 samples
# sample 175500 samples
# sample 176000 samples
# sample 176500 samples
# sample 177000 samples
# sample 177500 samples
# sample 178000 samples
# sample 178500 samples
# sample 179000 samples
# sample 179500 samples
# sample 180000 samples
# sample 180500 samples
# sample 181000 samples
# sample 181500 samples
# sample 182000 samples
# sample 182500 samples
# sample 183000 samples
# sample 183500 samples
# sample 184000 samples
# sample 184500 samples
# sample 185000 samples
# sample 185500 samples
# sample 186000 samples
# sample 186500 samples
# sample 187000 samples
# sample 187500 samples
# sample 188000 samples
# sample 188500 samples
# sample 189000 samples
# sample 189500 samples
# sample 190000 samples
# sample 190500 samples
# sample 191000 samples
# sample 191500 samples
# sample 192000 samples
# sample 192500 samples
# sample 193000 samples
# sample 193500 samples
# sample 194000 samples
# sample 194500 samples
# sample 195000 samples
# sample 195500 samples
# sample 196000 samples
# sample 196500 samples
# sample 197000 samples
# sample 197500 samples
# sample 198000 samples
# sample 198500 samples
# sample 199000 samples
# sample 199500 samples
# sample 200000 samples
# sample 200500 samples
# sample 201000 samples
# sample 201500 samples
# sample 202000 samples
# sample 202500 samples
# sample 203000 samples
# sample 203500 samples
# sample 204000 samples
# sample 204500 samples
# sample 205000 samples
# sample 205500 samples
# sample 206000 samples
# sample 206500 samples
# sample 207000 samples
# sample 207500 samples
# sample 208000 samples
# sample 208500 samples
# sample 209000 samples
# sample 209500 samples
# sample 210000 samples
# sample 210500 samples
# sample 211000 samples
# sample 211500 samples
# sample 212000 samples
# sample 212500 samples
# sample 213000 samples
# sample 213500 samples
# sample 214000 samples
# sample 214500 samples
# sample 215000 samples
# sample 215500 samples
# sample 216000 samples
# sample 216500 samples
# sample 217000 samples
# sample 217500 samples
# sample 218000 samples
# sample 218500 samples
# sample 219000 samples
# sample 219500 samples
# sample 220000 samples
# sample 220500 samples
# sample 221000 samples
# sample 221500 samples
# sample 222000 samples
# sample 222500 samples
# sample 223000 samples
# sample 223500 samples
# sample 224000 samples
# sample 224500 samples
# sample 225000 samples
# sample 225500 samples
# sample 226000 samples
# sample 226500 samples
# sample 227000 samples
# sample 227500 samples
# sample 228000 samples
# sample 228500 samples
# sample 229000 samples
# sample 229500 samples
# sample 230000 samples
# sample 230500 samples
# sample 231000 samples
# sample 231500 samples
# sample 232000 samples
# sample 232500 samples
# sample 233000 samples
# sample 233500 samples
# sample 234000 samples
# sample 234500 samples
# sample 235000 samples
# sample 235500 samples
# sample 236000 samples
# sample 236500 samples
# sample 237000 samples
# sample 237500 samples
# sample 238000 samples
# sample 238500 samples
# sample 239000 samples
# sample 239500 samples
# sample 240000 samples
# sample 240500 samples
# sample 241000 samples
# sample 241500 samples
# sample 242000 samples
# sample 242500 samples
# sample 243000 samples
# sample 243500 samples
# sample 244000 samples
# sample 244500 samples
# sample 245000 samples
# sample 245500 samples
# sample 246000 samples
# sample 246500 samples
# sample 247000 samples
# sample 247500 samples
# sample 248000 samples
# sample 248500 samples
# sample 249000 samples
# sample 249500 samples
# sample 250000 samples
# sample 250500 samples
# sample 251000 samples
# sample 251500 samples
# sample 252000 samples
# sample 252500 samples
# sample 253000 samples
# sample 253500 samples
# sample 254000 samples
# sample 254500 samples
# sample 255000 samples
# sample 255500 samples
# sample 256000 samples
# sample 256500 samples
# sample 257000 samples
# sample 257500 samples
# sample 258000 samples
# sample 258500 samples
# sample 259000 samples
# sample 259500 samples
# sample 260000 samples
# sample 260500 samples
# sample 261000 samples
# sample 261500 samples
# sample 262000 samples
# sample 262500 samples
# sample 263000 samples
# sample 263500 samples
# sample 264000 samples
# sample 264500 samples
# sample 265000 samples
# sample 265500 samples
# sample 266000 samples
# sample 266500 samples
# sample 267000 samples
# sample 267500 samples
# sample 268000 samples
# sample 268500 samples
# sample 269000 samples
# sample 269500 samples
# sample 270000 samples
# sample 270500 samples
# sample 271000 samples
# sample 271500 samples
# sample 272000 samples
# sample 272500 samples
# sample 273000 samples
# sample 273500 samples
# sample 274000 samples
# sample 274500 samples
# sample 275000 samples
# sample 275500 samples
# sample 276000 samples
# sample 276500 samples
# sample 277000 samples
# sample 277500 samples
# sample 278000 samples
# sample 278500 samples
# sample 279000 samples
# sample 279500 samples
# sample 280000 samples
# sample 280500 samples
# sample 281000 samples
# sample 281500 samples
# sample 282000 samples
# sample 282500 samples
# sample 283000 samples
# sample 283500 samples
# sample 284000 samples
# sample 284500 samples
# sample 285000 samples
# sample 285500 samples
# sample 286000 samples
# sample 286500 samples
# sample 287000 samples
# sample 287500 samples
# sample 288000 samples
# sample 288500 samples
# sample 289000 samples
# sample 289500 samples
# sample 290000 samples
# sample 290500 samples
# sample 291000 samples
# sample 291500 samples
# sample 292000 samples
# sample 292500 samples
# sample 293000 samples
# sample 293500 samples
# sample 294000 samples
# sample 294500 samples
# sample 295000 samples
# sample 295500 samples
# sample 296000 samples
# sample 296500 samples
# sample 297000 samples
# sample 297500 samples
# sample 298000 samples
# sample 298500 samples
# sample 299000 samples
# sample 299500 samples
# sample 300000 samples
# sample 300500 samples
# sample 301000 samples
# sample 301500 samples
# sample 302000 samples
# sample 302500 samples
# sample 303000 samples
# sample 303500 samples
# sample 304000 samples
# sample 304500 samples
# sample 305000 samples
# sample 305500 samples
# sample 306000 samples
# sample 306500 samples
# sample 307000 samples
# sample 307500 samples
# sample 308000 samples
# sample 308500 samples
# sample 309000 samples
# sample 309500 samples
# sample 310000 samples
# sample 310500 samples
# sample 311000 samples
# sample 311500 samples
# sample 312000 samples
# sample 312500 samples
# sample 313000 samples
# sample 313500 samples
# sample 314000 samples
# sample 314500 samples
# sample 315000 samples
# sample 315500 samples
# sample 316000 samples
# sample 316500 samples
# sample 317000 samples
# sample 317500 samples
# sample 318000 samples
# sample 318500 samples
# sample 319000 samples
# sample 319500 samples
# sample 320000 samples
# sample 320500 samples
# sample 321000 samples
# sample 321500 samples
# sample 322000 samples
# sample 322500 samples
# sample 323000 samples
# sample 323500 samples
# sample 324000 samples
# sample 324500 samples
# sample 325000 samples
# sample 325500 samples
# sample 326000 samples
# sample 326500 samples
# sample 327000 samples
# sample 327500 samples
# sample 328000 samples
# sample 328500 samples
# sample 329000 samples
# sample 329500 samples
# sample 330000 samples
# sample 330500 samples
# sample 331000 samples
# sample 331500 samples
# sample 332000 samples
# sample 332500 samples
# sample 333000 samples
# sample 333500 samples
# sample 334000 samples
# sample 334500 samples
# sample 335000 samples
# sample 335500 samples
# sample 336000 samples
# sample 336500 samples
# sample 337000 samples
# sample 337500 samples
# sample 338000 samples
# sample 338500 samples
# sample 339000 samples
# sample 339500 samples
# sample 340000 samples
# sample 340500 samples
# sample 341000 samples
# sample 341500 samples
# sample 342000 samples
# sample 342500 samples
# sample 343000 samples
# sample 343500 samples
# sample 344000 samples
# sample 344500 samples
# sample 345000 samples
# sample 345500 samples
# sample 346000 samples
# sample 346500 samples
# sample 347000 samples
# sample 347500 samples
# sample 348000 samples
# sample 348500 samples
# sample 349000 samples
# sample 349500 samples
# sample 350000 samples
# sample 350500 samples
# sample 351000 samples
# sample 351500 samples
# sample 352000 samples
# sample 352500 samples
# sample 353000 samples
# sample 353500 samples
# sample 354000 samples
# sample 354500 samples
# sample 355000 samples
# sample 355500 samples
# sample 356000 samples
# sample 356500 samples
# sample 357000 samples
# sample 357500 samples
# sample 358000 samples
# sample 358500 samples
# sample 359000 samples
# sample 359500 samples
# sample 360000 samples
# sample 360500 samples
# sample 361000 samples
# sample 361500 samples
# sample 362000 samples
# sample 362500 samples
# sample 363000 samples
# sample 363500 samples
# sample 364000 samples
# sample 364500 samples
# sample 365000 samples
# sample 365500 samples
# sample 366000 samples
# sample 366500 samples
# sample 367000 samples
# sample 367500 samples
# sample 368000 samples
# sample 368500 samples
# sample 369000 samples
# sample 369500 samples
# sample 370000 samples
# sample 370500 samples
# sample 371000 samples
# sample 371500 samples
# sample 372000 samples
# sample 372500 samples
# sample 373000 samples
# sample 373500 samples
# sample 374000 samples
# sample 374500 samples
# sample 375000 samples
# sample 375500 samples
# sample 376000 samples
# sample 376500 samples
# sample 377000 samples
# sample 377500 samples
# sample 378000 samples
# sample 378500 samples
# sample 379000 samples
# sample 379500 samples
# sample 380000 samples
# sample 380500 samples
# sample 381000 samples
# sample 381500 samples
# sample 382000 samples
# sample 382500 samples
# sample 383000 samples
# sample 383500 samples
# sample 384000 samples
# sample 384500 samples
# sample 385000 samples
# sample 385500 samples
# sample 386000 samples
# sample 386500 samples
# sample 387000 samples
# sample 387500 samples
# sample 388000 samples
# sample 388500 samples
# sample 389000 samples
# sample 389500 samples
# sample 390000 samples
# sample 390500 samples
# sample 391000 samples
# sample 391500 samples
# sample 392000 samples
# sample 392500 samples
# sample 393000 samples
# sample 393500 samples
# sample 394000 samples
# sample 394500 samples
# sample 395000 samples
# sample 395500 samples
# sample 396000 samples
# sample 396500 samples
# sample 397000 samples
# sample 397500 samples
# sample 398000 samples
# sample 398500 samples
# sample 399000 samples
# sample 399500 samples
# sample 400000 samples
# sample 400500 samples
# sample 401000 samples
# sample 401500 samples
# sample 402000 samples
# sample 402500 samples
# sample 403000 samples
# sample 403500 samples
# sample 404000 samples
# sample 404500 samples
# sample 405000 samples
# sample 405500 samples
# sample 406000 samples
# sample 406500 samples
# sample 407000 samples
# sample 407500 samples
# sample 408000 samples
# sample 408500 samples
# sample 409000 samples
# sample 409500 samples
# sample 410000 samples
# sample 410500 samples
# sample 411000 samples
# sample 411500 samples
# sample 412000 samples
# sample 412500 samples
# sample 413000 samples
# sample 413500 samples
# sample 414000 samples
# sample 414500 samples
# sample 415000 samples
# sample 415500 samples
# sample 416000 samples
# sample 416500 samples
# sample 417000 samples
# sample 417500 samples
# sample 418000 samples
# sample 418500 samples
# sample 419000 samples
# sample 419500 samples
# sample 420000 samples
# sample 420500 samples
# sample 421000 samples
# sample 421500 samples
# sample 422000 samples
# sample 422500 samples
# sample 423000 samples
# sample 423500 samples
# sample 424000 samples
# sample 424500 samples
# sample 425000 samples
# sample 425500 samples
# sample 426000 samples
# sample 426500 samples
# sample 427000 samples
# sample 427500 samples
# sample 428000 samples
# sample 428500 samples
# sample 429000 samples
# sample 429500 samples
# sample 430000 samples
# sample 430500 samples
# sample 431000 samples
# sample 431500 samples
# sample 432000 samples
# sample 432500 samples
# sample 433000 samples
# sample 433500 samples
# sample 434000 samples
# sample 434500 samples
# sample 435000 samples
# sample 435500 samples
# sample 436000 samples
# sample 436500 samples
# sample 437000 samples
# sample 437500 samples
# sample 438000 samples
# sample 438500 samples
# sample 439000 samples
# sample 439500 samples
# sample 440000 samples
# sample 440500 samples
# sample 441000 samples
# sample 441500 samples
# sample 442000 samples
# sample 442500 samples
# sample 443000 samples
# sample 443500 samples
# sample 444000 samples
# sample 444500 samples
# sample 445000 samples
# sample 445500 samples
# sample 446000 samples
# sample 446500 samples
# sample 447000 samples
# sample 447500 samples
# sample 448000 samples
# sample 448500 samples
# sample 449000 samples
# sample 449500 samples
# sample 450000 samples
# sample 450500 samples
# sample 451000 samples
# sample 451500 samples
# sample 452000 samples
# sample 452500 samples
# sample 453000 samples
# sample 453500 samples
# sample 454000 samples
# sample 454500 samples
# sample 455000 samples
# sample 455500 samples
# sample 456000 samples
# sample 456500 samples
# sample 457000 samples
# sample 457500 samples
# sample 458000 samples
# sample 458500 samples
# sample 459000 samples
# sample 459500 samples
# sample 460000 samples
# sample 460500 samples
# sample 461000 samples
# sample 461500 samples
# sample 462000 samples
# sample 462500 samples
# sample 463000 samples
# sample 463500 samples
# sample 464000 samples
# sample 464500 samples
# sample 465000 samples
# sample 465500 samples
# sample 466000 samples
# sample 466500 samples
# sample 467000 samples
# sample 467500 samples
# sample 468000 samples
# sample 468500 samples
# sample 469000 samples
# sample 469500 samples
# sample 470000 samples
# sample 470500 samples
# sample 471000 samples
# sample 471500 samples
# sample 472000 samples
# sample 472500 samples
# sample 473000 samples
# sample 473500 samples
# sample 474000 samples
# sample 474500 samples
# sample 475000 samples
# sample 475500 samples
# sample 476000 samples
# sample 476500 samples
# sample 477000 samples
# sample 477500 samples
# sample 478000 samples
# sample 478500 samples
# sample 479000 samples
# sample 479500 samples
# sample 480000 samples
# sample 480500 samples
# sample 481000 samples
# sample 481500 samples
# sample 482000 samples
# sample 482500 samples
# sample 483000 samples
# sample 483500 samples
# sample 484000 samples
# sample 484500 samples
# sample 485000 samples
# sample 485500 samples
# sample 486000 samples
# sample 486500 samples
# sample 487000 samples
# sample 487500 samples
# sample 488000 samples
# sample 488500 samples
# sample 489000 samples
# sample 489500 samples
# sample 490000 samples
# sample 490500 samples
# sample 491000 samples
# sample 491500 samples
# sample 492000 samples
# sample 492500 samples
# sample 493000 samples
# sample 493500 samples
# sample 494000 samples
# sample 494500 samples
# sample 495000 samples
# sample 495500 samples
# sample 496000 samples
# sample 496500 samples
# sample 497000 samples
# sample 497500 samples
# sample 498000 samples
# sample 498500 samples
# sample 499000 samples
# sample 499500 samples
# sample 500000 samples
# sample 500500 samples
# sample 501000 samples
# sample 501500 samples
# sample 502000 samples
# sample 502500 samples
# sample 503000 samples
# sample 503500 samples
# sample 504000 samples
# sample 504500 samples
# sample 505000 samples
# sample 505500 samples
# sample 506000 samples
# sample 506500 samples
# sample 507000 samples
# sample 507500 samples
# sample 508000 samples
# sample 508500 samples
# sample 509000 samples
# sample 509500 samples
# sample 510000 samples
# sample 510500 samples
# sample 511000 samples
# sample 511500 samples
# sample 512000 samples
# sample 512500 samples
# sample 513000 samples
# sample 513500 samples
# sample 514000 samples
# sample 514500 samples
# sample 515000 samples
# sample 515500 samples
# sample 516000 samples
# sample 516500 samples
# sample 517000 samples
# sample 517500 samples
# sample 518000 samples
# sample 518500 samples
# sample 519000 samples
# sample 519500 samples
# sample 520000 samples
# sample 520500 samples
# sample 521000 samples
# sample 521500 samples
# sample 522000 samples
# sample 522500 samples
# sample 523000 samples
# sample 523500 samples
# sample 524000 samples
# sample 524500 samples
# sample 525000 samples
# sample 525500 samples
# sample 526000 samples
# sample 526500 samples
# sample 527000 samples
# sample 527500 samples
# sample 528000 samples
# sample 528500 samples
# sample 529000 samples
# sample 529500 samples
# sample 530000 samples
# sample 530500 samples
# sample 531000 samples
# sample 531500 samples
# sample 532000 samples
# sample 532500 samples
# sample 533000 samples
# sample 533500 samples
# sample 534000 samples
# sample 534500 samples
# sample 535000 samples
# sample 535500 samples
# sample 536000 samples
# sample 536500 samples
# sample 537000 samples
# sample 537500 samples
# sample 538000 samples
# sample 538500 samples
# sample 539000 samples
# sample 539500 samples
# sample 540000 samples
# sample 540500 samples
# sample 541000 samples
# sample 541500 samples
# sample 542000 samples
# sample 542500 samples
# sample 543000 samples
# sample 543500 samples
# sample 544000 samples
# sample 544500 samples
# sample 545000 samples
# sample 545500 samples
# sample 546000 samples
# sample 546500 samples
# sample 547000 samples
# sample 547500 samples
# sample 548000 samples
# sample 548500 samples
# sample 549000 samples
# sample 549500 samples
# sample 550000 samples
# sample 550500 samples
# sample 551000 samples
# sample 551500 samples
# sample 552000 samples
# sample 552500 samples
# sample 553000 samples
# sample 553500 samples
# sample 554000 samples
# sample 554500 samples
# sample 555000 samples
# sample 555500 samples
# sample 556000 samples
# sample 556500 samples
# sample 557000 samples
# sample 557500 samples
# sample 558000 samples
# sample 558500 samples
# sample 559000 samples
# sample 559500 samples
# sample 560000 samples
# sample 560500 samples
# sample 561000 samples
# sample 561500 samples
# sample 562000 samples
# sample 562500 samples
# sample 563000 samples
# sample 563500 samples
# sample 564000 samples
# sample 564500 samples
# sample 565000 samples
# sample 565500 samples
# sample 566000 samples
# sample 566500 samples
# sample 567000 samples
# sample 567500 samples
# sample 568000 samples
# sample 568500 samples
# sample 569000 samples
# sample 569500 samples
# sample 570000 samples
# sample 570500 samples
# sample 571000 samples
# sample 571500 samples
# sample 572000 samples
# sample 572500 samples
# sample 573000 samples
# sample 573500 samples
# sample 574000 samples
# sample 574500 samples
# sample 575000 samples
# sample 575500 samples
# sample 576000 samples
# sample 576500 samples
# sample 577000 samples
# sample 577500 samples
# sample 578000 samples
# sample 578500 samples
# sample 579000 samples
# sample 579500 samples
# sample 580000 samples
# sample 580500 samples
# sample 581000 samples
# sample 581500 samples
# sample 582000 samples
# sample 582500 samples
# sample 583000 samples
# sample 583500 samples
# sample 584000 samples
# sample 584500 samples
# sample 585000 samples
# sample 585500 samples
# sample 586000 samples
# sample 586500 samples
# sample 587000 samples
# sample 587500 samples
# sample 588000 samples
# sample 588500 samples
# sample 589000 samples
# sample 589500 samples
# sample 590000 samples
# sample 590500 samples
# sample 591000 samples
# sample 591500 samples
# sample 592000 samples
# sample 592500 samples
# sample 593000 samples
# sample 593500 samples
# sample 594000 samples
# sample 594500 samples
# sample 595000 samples
# sample 595500 samples
# sample 596000 samples
# sample 596500 samples
# sample 597000 samples
# sample 597500 samples
# sample 598000 samples
# sample 598500 samples
# sample 599000 samples
# sample 599500 samples
# sample 600000 samples
# sample 600500 samples
# sample 601000 samples
# sample 601500 samples
# sample 602000 samples
# sample 602500 samples
# sample 603000 samples
# sample 603500 samples
# sample 604000 samples
# sample 604500 samples
# sample 605000 samples
# sample 605500 samples
# sample 606000 samples
# sample 606500 samples
# sample 607000 samples
# sample 607500 samples
# sample 608000 samples
# sample 608500 samples
# sample 609000 samples
# sample 609500 samples
# sample 610000 samples
# sample 610500 samples
# sample 611000 samples
# sample 611500 samples
# sample 612000 samples
# sample 612500 samples
# sample 613000 samples
# sample 613500 samples
# sample 614000 samples
# sample 614500 samples
# sample 615000 samples
# sample 615500 samples
# sample 616000 samples
# sample 616500 samples
# sample 617000 samples
# sample 617500 samples
# sample 618000 samples
# sample 618500 samples
# sample 619000 samples
# sample 619500 samples
# sample 620000 samples
# sample 620500 samples
# sample 621000 samples
# sample 621500 samples
# sample 622000 samples
# sample 622500 samples
# sample 623000 samples
# sample 623500 samples
# sample 624000 samples
# sample 624500 samples
# sample 625000 samples
# sample 625500 samples
# sample 626000 samples
# sample 626500 samples
# sample 627000 samples
# sample 627500 samples
# sample 628000 samples
# sample 628500 samples
# sample 629000 samples
# sample 629500 samples
# sample 630000 samples
# sample 630500 samples
# sample 631000 samples
# sample 631500 samples
# sample 632000 samples
# sample 632500 samples
# sample 633000 samples
# sample 633500 samples
# sample 634000 samples
# sample 634500 samples
# sample 635000 samples
# sample 635500 samples
# sample 636000 samples
# sample 636500 samples
# sample 637000 samples
# sample 637500 samples
# sample 638000 samples
# sample 638500 samples
# sample 639000 samples
# sample 639500 samples
# sample 640000 samples
# sample 640500 samples
# sample 641000 samples
# sample 641500 samples
# sample 642000 samples
# sample 642500 samples
# sample 643000 samples
# sample 643500 samples
# sample 644000 samples
# sample 644500 samples
# sample 645000 samples
# sample 645500 samples
# sample 646000 samples
# sample 646500 samples
# sample 647000 samples
# sample 647500 samples
# sample 648000 samples
# sample 648500 samples
# sample 649000 samples
# sample 649500 samples
# sample 650000 samples
# sample 650500 samples
# sample 651000 samples
# sample 651500 samples
# sample 652000 samples
# sample 652500 samples
# sample 653000 samples
# sample 653500 samples
# sample 654000 samples
# sample 654500 samples
# sample 655000 samples
# sample 655500 samples
# sample 656000 samples
# sample 656500 samples
# sample 657000 samples
# sample 657500 samples
# sample 658000 samples
# sample 658500 samples
# sample 659000 samples
# sample 659500 samples
# sample 660000 samples
# sample 660500 samples
# sample 661000 samples
# sample 661500 samples
# sample 662000 samples
# sample 662500 samples
# sample 663000 samples
# sample 663500 samples
# sample 664000 samples
# sample 664500 samples
# sample 665000 samples
# sample 665500 samples
# sample 666000 samples
# sample 666500 samples
# sample 667000 samples
# sample 667500 samples
# sample 668000 samples
# sample 668500 samples
# sample 669000 samples
# sample 669500 samples
# sample 670000 samples
# sample 670500 samples
# sample 671000 samples
# sample 671500 samples
# sample 672000 samples
# sample 672500 samples
# sample 673000 samples
# sample 673500 samples
# sample 674000 samples
# sample 674500 samples
# sample 675000 samples
# sample 675500 samples
# sample 676000 samples
# sample 676500 samples
# sample 677000 samples
# sample 677500 samples
# sample 678000 samples
# sample 678500 samples
# sample 679000 samples
# sample 679500 samples
# sample 680000 samples
# sample 680500 samples
# sample 681000 samples
# sample 681500 samples
# sample 682000 samples
# sample 682500 samples
# sample 683000 samples
# sample 683500 samples
# sample 684000 samples
# sample 684500 samples
# sample 685000 samples
# sample 685500 samples
# sample 686000 samples
# sample 686500 samples
# sample 687000 samples
# sample 687500 samples
# sample 688000 samples
# sample 688500 samples
# sample 689000 samples
# sample 689500 samples
# sample 690000 samples
# sample 690500 samples
# sample 691000 samples
# sample 691500 samples
# sample 692000 samples
# sample 692500 samples
# sample 693000 samples
# sample 693500 samples
# sample 694000 samples
# sample 694500 samples
# sample 695000 samples
# sample 695500 samples
# sample 696000 samples
# sample 696500 samples
# sample 697000 samples
# sample 697500 samples
# sample 698000 samples
# sample 698500 samples
# sample 699000 samples
# sample 699500 samples
# sample 700000 samples
# sample 700500 samples
# sample 701000 samples
# sample 701500 samples
# sample 702000 samples
# sample 702500 samples
# sample 703000 samples
# sample 703500 samples
# sample 704000 samples
# sample 704500 samples
# sample 705000 samples
# sample 705500 samples
# sample 706000 samples
# sample 706500 samples
# sample 707000 samples
# sample 707500 samples
# sample 708000 samples
# sample 708500 samples
# sample 709000 samples
# sample 709500 samples
# sample 710000 samples
# sample 710500 samples
# sample 711000 samples
# sample 711500 samples
# sample 712000 samples
# sample 712500 samples
# sample 713000 samples
# sample 713500 samples
# sample 714000 samples
# sample 714500 samples
# sample 715000 samples
# sample 715500 samples
# sample 716000 samples
# sample 716500 samples
# sample 717000 samples
# sample 717500 samples
# sample 718000 samples
# sample 718500 samples
# sample 719000 samples
# sample 719500 samples
# sample 720000 samples
# sample 720500 samples
# sample 721000 samples
# sample 721500 samples
# sample 722000 samples
# sample 722500 samples
# sample 723000 samples
# sample 723500 samples
# sample 724000 samples
# sample 724500 samples
# sample 725000 samples
# sample 725500 samples
# sample 726000 samples
# sample 726500 samples
# sample 727000 samples
# sample 727500 samples
# sample 728000 samples
# sample 728500 samples
# sample 729000 samples
# sample 729500 samples
# sample 730000 samples
# sample 730500 samples
# sample 731000 samples
# sample 731500 samples
# sample 732000 samples
# sample 732500 samples
# sample 733000 samples
# sample 733500 samples
# sample 734000 samples
# sample 734500 samples
# sample 735000 samples
# sample 735500 samples
# sample 736000 samples
# sample 736500 samples
# sample 737000 samples
# sample 737500 samples
# sample 738000 samples
# sample 738500 samples
# sample 739000 samples
# sample 739500 samples
# sample 740000 samples
# sample 740500 samples
# sample 741000 samples
# sample 741500 samples
# sample 742000 samples
# sample 742500 samples
# sample 743000 samples
# sample 743500 samples
# sample 744000 samples
# sample 744500 samples
# sample 745000 samples
# sample 745500 samples
# sample 746000 samples
# sample 746500 samples
# sample 747000 samples
# sample 747500 samples
# sample 748000 samples
# sample 748500 samples
# sample 749000 samples
# sample 749500 samples
# sample 750000 samples
# sample 750500 samples
# sample 751000 samples
# sample 751500 samples
# sample 752000 samples
# sample 752500 samples
# sample 753000 samples
# sample 753500 samples
# sample 754000 samples
# sample 754500 samples
# sample 755000 samples
# sample 755500 samples
# sample 756000 samples
# sample 756500 samples
# sample 757000 samples
# sample 757500 samples
# sample 758000 samples
# sample 758500 samples
# sample 759000 samples
# sample 759500 samples
# sample 760000 samples
# sample 760500 samples
# sample 761000 samples
# sample 761500 samples
# sample 762000 samples
# sample 762500 samples
# sample 763000 samples
# sample 763500 samples
# sample 764000 samples
# sample 764500 samples
# sample 765000 samples
# sample 765500 samples
# sample 766000 samples
# sample 766500 samples
# sample 767000 samples
# sample 767500 samples
# sample 768000 samples
# sample 768500 samples
# sample 769000 samples
# sample 769500 samples
# sample 770000 samples
# sample 770500 samples
# sample 771000 samples
# sample 771500 samples
# sample 772000 samples
# sample 772500 samples
# sample 773000 samples
# sample 773500 samples
# sample 774000 samples
# sample 774500 samples
# sample 775000 samples
# sample 775500 samples
# sample 776000 samples
# sample 776500 samples
# sample 777000 samples
# sample 777500 samples
# sample 778000 samples
# sample 778500 samples
# sample 779000 samples
# sample 779500 samples
# sample 780000 samples
# sample 780500 samples
# sample 781000 samples
# sample 781500 samples
# sample 782000 samples
# sample 782500 samples
# sample 783000 samples
# sample 783500 samples
# sample 784000 samples
# sample 784500 samples
# sample 785000 samples
# sample 785500 samples
# sample 786000 samples
# sample 786500 samples
# sample 787000 samples
# sample 787500 samples
# sample 788000 samples
# sample 788500 samples
# sample 789000 samples
# sample 789500 samples
# sample 790000 samples
# sample 790500 samples
# sample 791000 samples
# sample 791500 samples
# sample 792000 samples
# sample 792500 samples
# sample 793000 samples
# sample 793500 samples
# sample 794000 samples
# sample 794500 samples
# sample 795000 samples
# sample 795500 samples
# sample 796000 samples
# sample 796500 samples
# sample 797000 samples
# sample 797500 samples
# sample 798000 samples
# sample 798500 samples
# sample 799000 samples
# sample 799500 samples
# sample 800000 samples
# sample 800500 samples
# sample 801000 samples
# sample 801500 samples
# sample 802000 samples
# sample 802500 samples
# sample 803000 samples
# sample 803500 samples
# sample 804000 samples
# sample 804500 samples
# sample 805000 samples
# sample 805500 samples
# sample 806000 samples
# sample 806500 samples
# sample 807000 samples
# sample 807500 samples
# sample 808000 samples
# sample 808500 samples
# sample 809000 samples
# sample 809500 samples
# sample 810000 samples
# sample 810500 samples
# sample 811000 samples
# sample 811500 samples
# sample 812000 samples
# sample 812500 samples
# sample 813000 samples
# sample 813500 samples
# sample 814000 samples
# sample 814500 samples
# sample 815000 samples
# sample 815500 samples
# sample 816000 samples
# sample 816500 samples
# sample 817000 samples
# sample 817500 samples
# sample 818000 samples
# sample 818500 samples
# sample 819000 samples
# sample 819500 samples
# sample 820000 samples
# sample 820500 samples
# sample 821000 samples
# sample 821500 samples
# sample 822000 samples
# sample 822500 samples
# sample 823000 samples
# sample 823500 samples
# sample 824000 samples
# sample 824500 samples
# sample 825000 samples
# sample 825500 samples
# sample 826000 samples
# sample 826500 samples
# sample 827000 samples
# sample 827500 samples
# sample 828000 samples
# sample 828500 samples
# sample 829000 samples
# sample 829500 samples
# sample 830000 samples
# sample 830500 samples
# sample 831000 samples
# sample 831500 samples
# sample 832000 samples
# sample 832500 samples
# sample 833000 samples
# sample 833500 samples
# sample 834000 samples
# sample 834500 samples
# sample 835000 samples
# sample 835500 samples
# sample 836000 samples
# sample 836500 samples
# sample 837000 samples
# sample 837500 samples
# sample 838000 samples
# sample 838500 samples
# sample 839000 samples
# sample 839500 samples
# sample 840000 samples
# sample 840500 samples
# sample 841000 samples
# sample 841500 samples
# sample 842000 samples
# sample 842500 samples
# sample 843000 samples
# sample 843500 samples
# sample 844000 samples
# sample 844500 samples
# sample 845000 samples
# sample 845500 samples
# sample 846000 samples
# sample 846500 samples
# sample 847000 samples
# sample 847500 samples
# sample 848000 samples
# sample 848500 samples
# sample 849000 samples
# sample 849500 samples
# sample 850000 samples
# sample 850500 samples
# sample 851000 samples
# sample 851500 samples
# sample 852000 samples
# sample 852500 samples
# sample 853000 samples
# sample 853500 samples
# sample 854000 samples
# sample 854500 samples
# sample 855000 samples
# sample 855500 samples
# sample 856000 samples
# sample 856500 samples
# sample 857000 samples
# sample 857500 samples
# sample 858000 samples
# sample 858500 samples
# sample 859000 samples
# sample 859500 samples
# sample 860000 samples
# sample 860500 samples
# sample 861000 samples
# sample 861500 samples
# sample 862000 samples
# sample 862500 samples
# sample 863000 samples
# sample 863500 samples
# sample 864000 samples
# sample 864500 samples
# sample 865000 samples
# sample 865500 samples
# sample 866000 samples
# sample 866500 samples
# sample 867000 samples
# sample 867500 samples
# sample 868000 samples
# sample 868500 samples
# sample 869000 samples
# sample 869500 samples
# sample 870000 samples
# sample 870500 samples
# sample 871000 samples
# sample 871500 samples
# sample 872000 samples
# sample 872500 samples
# sample 873000 samples
# sample 873500 samples
# sample 874000 samples
# sample 874500 samples
# sample 875000 samples
# sample 875500 samples
# sample 876000 samples
# sample 876500 samples
# sample 877000 samples
# sample 877500 samples
# sample 878000 samples
# sample 878500 samples
# sample 879000 samples
# sample 879500 samples
# sample 880000 samples
# sample 880500 samples
# sample 881000 samples
# sample 881500 samples
# sample 882000 samples
# sample 882500 samples
# sample 883000 samples
# sample 883500 samples
# sample 884000 samples
# sample 884500 samples
# sample 885000 samples
# sample 885500 samples
# sample 886000 samples
# sample 886500 samples
# sample 887000 samples
# sample 887500 samples
# sample 888000 samples
# sample 888500 samples
# sample 889000 samples
# sample 889500 samples
# sample 890000 samples
# sample 890500 samples
# sample 891000 samples
# sample 891500 samples
# sample 892000 samples
# sample 892500 samples
# sample 893000 samples
# sample 893500 samples
# sample 894000 samples
# sample 894500 samples
# sample 895000 samples
# sample 895500 samples
# sample 896000 samples
# sample 896500 samples
# sample 897000 samples
# sample 897500 samples
# sample 898000 samples
# sample 898500 samples
# sample 899000 samples
# sample 899500 samples
# sample 900000 samples
# sample 900500 samples
# sample 901000 samples
# sample 901500 samples
# sample 902000 samples
# sample 902500 samples
# sample 903000 samples
# sample 903500 samples
# sample 904000 samples
# sample 904500 samples
# sample 905000 samples
# sample 905500 samples
# sample 906000 samples
# sample 906500 samples
# sample 907000 samples
# sample 907500 samples
# sample 908000 samples
# sample 908500 samples
# sample 909000 samples
# sample 909500 samples
# sample 910000 samples
# sample 910500 samples
# sample 911000 samples
# sample 911500 samples
# sample 912000 samples
# sample 912500 samples
# sample 913000 samples
# sample 913500 samples
# sample 914000 samples
# sample 914500 samples
# sample 915000 samples
# sample 915500 samples
# sample 916000 samples
# sample 916500 samples
# sample 917000 samples
# sample 917500 samples
# sample 918000 samples
# sample 918500 samples
# sample 919000 samples
# sample 919500 samples
# sample 920000 samples
# sample 920500 samples
# sample 921000 samples
# sample 921500 samples
# sample 922000 samples
# sample 922500 samples
# sample 923000 samples
# sample 923500 samples
# sample 924000 samples
# sample 924500 samples
# sample 925000 samples
# sample 925500 samples
# sample 926000 samples
# sample 926500 samples
# sample 927000 samples
# sample 927500 samples
# sample 928000 samples
# sample 928500 samples
# sample 929000 samples
# sample 929500 samples
# sample 930000 samples
# sample 930500 samples
# sample 931000 samples
# sample 931500 samples
# sample 932000 samples
# sample 932500 samples
# sample 933000 samples
# sample 933500 samples
# sample 934000 samples
# sample 934500 samples
# sample 935000 samples
# sample 935500 samples
# sample 936000 samples
# sample 936500 samples
# sample 937000 samples
# sample 937500 samples
# sample 938000 samples
# sample 938500 samples
# sample 939000 samples
# sample 939500 samples
# sample 940000 samples
# sample 940500 samples
# sample 941000 samples
# sample 941500 samples
# sample 942000 samples
# sample 942500 samples
# sample 943000 samples
# sample 943500 samples
# sample 944000 samples
# sample 944500 samples
# sample 945000 samples
# sample 945500 samples
# sample 946000 samples
# sample 946500 samples
# sample 947000 samples
# sample 947500 samples
# sample 948000 samples
# sample 948500 samples
# sample 949000 samples
# sample 949500 samples
# sample 950000 samples
# sample 950500 samples
# sample 951000 samples
# sample 951500 samples
# sample 952000 samples
# sample 952500 samples
# sample 953000 samples
# sample 953500 samples
# sample 954000 samples
# sample 954500 samples
# sample 955000 samples
# sample 955500 samples
# sample 956000 samples
# sample 956500 samples
# sample 957000 samples
# sample 957500 samples
# sample 958000 samples
# sample 958500 samples
# sample 959000 samples
# sample 959500 samples
# sample 960000 samples
# sample 960500 samples
# sample 961000 samples
# sample 961500 samples
# sample 962000 samples
# sample 962500 samples
# sample 963000 samples
# sample 963500 samples
# sample 964000 samples
# sample 964500 samples
# sample 965000 samples
# sample 965500 samples
# sample 966000 samples
# sample 966500 samples
# sample 967000 samples
# sample 967500 samples
# sample 968000 samples
# sample 968500 samples
# sample 969000 samples
# sample 969500 samples
# sample 970000 samples
# sample 970500 samples
# sample 971000 samples
# sample 971500 samples
# sample 972000 samples
# sample 972500 samples
# sample 973000 samples
# sample 973500 samples
# sample 974000 samples
# sample 974500 samples
# sample 975000 samples
# sample 975500 samples
# sample 976000 samples
# sample 976500 samples
# sample 977000 samples
# sample 977500 samples
# sample 978000 samples
# sample 978500 samples
# sample 979000 samples
# sample 979500 samples
# sample 980000 samples
# sample 980500 samples
# sample 981000 samples
# sample 981500 samples
# sample 982000 samples
# sample 982500 samples
# sample 983000 samples
# sample 983500 samples
# sample 984000 samples
# sample 984500 samples
# sample 985000 samples
# sample 985500 samples
# sample 986000 samples
# sample 986500 samples
# sample 987000 samples
# sample 987500 samples
# sample 988000 samples
# sample 988500 samples
# sample 989000 samples
# sample 989500 samples
# sample 990000 samples
# sample 990500 samples
# sample 991000 samples
# sample 991500 samples
# sample 992000 samples
# sample 992500 samples
# sample 993000 samples
# sample 993500 samples
# sample 994000 samples
# sample 994500 samples
# sample 995000 samples
# sample 995500 samples
# sample 996000 samples
# sample 996500 samples
# sample 997000 samples
# sample 997500 samples
# sample 998000 samples
# sample 998500 samples
# sample 999000 samples
# sample 999500 samples
# sample 1000000 samples
# sample 1000500 samples
# sample 1001000 samples
# sample 1001500 samples
# sample 1002000 samples
# sample 1002500 samples
# sample 1003000 samples
# sample 1003500 samples
# sample 1004000 samples
# sample 1004500 samples
# sample 1005000 samples
# sample 1005500 samples
# sample 1006000 samples
# sample 1006500 samples
# sample 1007000 samples
# sample 1007500 samples
# sample 1008000 samples
# sample 1008500 samples
# sample 1009000 samples
# sample 1009500 samples
# sample 1010000 samples
# sample 1010500 samples
# sample 1011000 samples
# sample 1011500 samples
# sample 1012000 samples
# sample 1012500 samples
# sample 1013000 samples
# sample 1013500 samples
# sample 1014000 samples
# sample 1014500 samples
# sample 1015000 samples
# sample 1015500 samples
# sample 1016000 samples
# sample 1016500 samples
# sample 1017000 samples
# sample 1017500 samples
# sample 1018000 samples
# sample 1018500 samples
# sample 1019000 samples
# sample 1019500 samples
# sample 1020000 samples
# sample 1020500 samples
# sample 1021000 samples
# sample 1021500 samples
# sample 1022000 samples
# sample 1022500 samples
# sample 1023000 samples
# sample 1023500 samples
# sample 1024000 samples
# sample 1024500 samples
# sample 1025000 samples
# sample 1025500 samples
# sample 1026000 samples
# sample 1026500 samples
# sample 1027000 samples
# sample 1027500 samples
# sample 1028000 samples
# sample 1028500 samples
# sample 1029000 samples
# sample 1029500 samples
# sample 1030000 samples
# sample 1030500 samples
# sample 1031000 samples
# sample 1031500 samples
# sample 1032000 samples
# sample 1032500 samples
# sample 1033000 samples
# sample 1033500 samples
# sample 1034000 samples
# sample 1034500 samples
# sample 1035000 samples
# sample 1035500 samples
# sample 1036000 samples
# sample 1036500 samples
# sample 1037000 samples
# sample 1037500 samples
# sample 1038000 samples
# sample 1038500 samples
# sample 1039000 samples
# sample 1039500 samples
# sample 1040000 samples
# sample 1040500 samples
# sample 1041000 samples
# sample 1041500 samples
# sample 1042000 samples
# sample 1042500 samples
# sample 1043000 samples
# sample 1043500 samples
# sample 1044000 samples
# sample 1044500 samples
# sample 1045000 samples
# sample 1045500 samples
# sample 1046000 samples
# sample 1046500 samples
# sample 1047000 samples
# sample 1047500 samples
# sample 1048000 samples
# sample 1048500 samples
# sample 1049000 samples
# sample 1049500 samples
# sample 1050000 samples
# sample 1050500 samples
# sample 1051000 samples
# sample 1051500 samples
# sample 1052000 samples
# sample 1052500 samples
# sample 1053000 samples
# sample 1053500 samples
# sample 1054000 samples
# sample 1054500 samples
# sample 1055000 samples
# sample 1055500 samples
# sample 1056000 samples
# sample 1056500 samples
# sample 1057000 samples
# sample 1057500 samples
# sample 1058000 samples
# sample 1058500 samples
# sample 1059000 samples
# sample 1059500 samples
# sample 1060000 samples
# sample 1060500 samples
# sample 1061000 samples
# sample 1061500 samples
# sample 1062000 samples
# sample 1062500 samples
# sample 1063000 samples
# sample 1063500 samples
# sample 1064000 samples
# sample 1064500 samples
# sample 1065000 samples
# sample 1065500 samples
# sample 1066000 samples
# sample 1066500 samples
# sample 1067000 samples
# sample 1067500 samples
# sample 1068000 samples
# sample 1068500 samples
# sample 1069000 samples
# sample 1069500 samples
# sample 1070000 samples
# sample 1070500 samples
# sample 1071000 samples
# sample 1071500 samples
# sample 1072000 samples
# sample 1072500 samples
# sample 1073000 samples
# sample 1073500 samples
# sample 1074000 samples
# sample 1074500 samples
# sample 1075000 samples
# sample 1075500 samples
# sample 1076000 samples
# sample 1076500 samples
# sample 1077000 samples
# sample 1077500 samples
# sample 1078000 samples
# sample 1078500 samples
# sample 1079000 samples
# sample 1079500 samples
# sample 1080000 samples
# sample 1080500 samples
# sample 1081000 samples
# sample 1081500 samples
# sample 1082000 samples
# sample 1082500 samples
# sample 1083000 samples
# sample 1083500 samples
# sample 1084000 samples
# sample 1084500 samples
# sample 1085000 samples
# sample 1085500 samples
# sample 1086000 samples
# sample 1086500 samples
# sample 1087000 samples
# sample 1087500 samples
# sample 1088000 samples
# sample 1088500 samples
# sample 1089000 samples
# sample 1089500 samples
# sample 1090000 samples
# sample 1090500 samples
# ...
# sample 9652500 samples
# sample 9653000 samples
# sample 9653500 samples
# sample 9654000 samples
# sample 9654500 samples
# sample 9655000 samples
# sample 9655500 samples
# sample 9656000 samples
# sample 9656500 samples
# sample 9657000 samples
# sample 9657500 samples
# sample 9658000 samples
# sample 9658500 samples
# sample 9659000 samples
# sample 9659500 samples
# sample 9660000 samples
# sample 9660500 samples
# sample 9661000 samples
# sample 9661500 samples
# sample 9662000 samples
# sample 9662500 samples
# sample 9663000 samples
# sample 9663500 samples
# sample 9664000 samples
# sample 9664500 samples
# sample 9665000 samples
# sample 9665500 samples
# sample 9666000 samples
# sample 9666500 samples
# sample 9667000 samples
# sample 9667500 samples
# sample 9668000 samples
# sample 9668500 samples
# sample 9669000 samples
# sample 9669500 samples
# sample 9670000 samples
# sample 9670500 samples
# sample 9671000 samples
# sample 9671500 samples
# sample 9672000 samples
# sample 9672500 samples
# sample 9673000 samples
# sample 9673500 samples
# sample 9674000 samples
# sample 9674500 samples
# sample 9675000 samples
# sample 9675500 samples
# sample 9676000 samples
# sample 9676500 samples
# sample 9677000 samples
# sample 9677500 samples
# sample 9678000 samples
# sample 9678500 samples
# sample 9679000 samples
# sample 9679500 samples
# sample 9680000 samples
# sample 9680500 samples
# sample 9681000 samples
# sample 9681500 samples
# sample 9682000 samples
# sample 9682500 samples
# sample 9683000 samples
# sample 9683500 samples
# sample 9684000 samples
# sample 9684500 samples
# sample 9685000 samples
# sample 9685500 samples
# sample 9686000 samples
# sample 9686500 samples
# sample 9687000 samples
# sample 9687500 samples
# sample 9688000 samples
# sample 9688500 samples
# sample 9689000 samples
# sample 9689500 samples
# sample 9690000 samples
# sample 9690500 samples
# sample 9691000 samples
# sample 9691500 samples
# sample 9692000 samples
# sample 9692500 samples
# sample 9693000 samples
# sample 9693500 samples
# sample 9694000 samples
# sample 9694500 samples
# sample 9695000 samples
# sample 9695500 samples
# sample 9696000 samples
# sample 9696500 samples
# sample 9697000 samples
# sample 9697500 samples
# sample 9698000 samples
# sample 9698500 samples
# sample 9699000 samples
# sample 9699500 samples
# sample 9700000 samples
# sample 9700500 samples
# sample 9701000 samples
# sample 9701500 samples
# sample 9702000 samples
# sample 9702500 samples
# sample 9703000 samples
# sample 9703500 samples
# sample 9704000 samples
# sample 9704500 samples
# sample 9705000 samples
# sample 9705500 samples
# sample 9706000 samples
# sample 9706500 samples
# sample 9707000 samples
# sample 9707500 samples
# sample 9708000 samples
# sample 9708500 samples
# sample 9709000 samples
# sample 9709500 samples
# sample 9710000 samples
# sample 9710500 samples
# sample 9711000 samples
# sample 9711500 samples
# sample 9712000 samples
# sample 9712500 samples
# sample 9713000 samples
# sample 9713500 samples
# sample 9714000 samples
# sample 9714500 samples
# sample 9715000 samples
# sample 9715500 samples
# sample 9716000 samples
# sample 9716500 samples
# sample 9717000 samples
# sample 9717500 samples
# sample 9718000 samples
# sample 9718500 samples
# sample 9719000 samples
# sample 9719500 samples
# sample 9720000 samples
# sample 9720500 samples
# sample 9721000 samples
# sample 9721500 samples
# sample 9722000 samples
# sample 9722500 samples
# sample 9723000 samples
# sample 9723500 samples
# sample 9724000 samples
# sample 9724500 samples
# sample 9725000 samples
# sample 9725500 samples
# sample 9726000 samples
# sample 9726500 samples
# sample 9727000 samples
# sample 9727500 samples
# sample 9728000 samples
# sample 9728500 samples
# sample 9729000 samples
# sample 9729500 samples
# sample 9730000 samples
# sample 9730500 samples
# sample 9731000 samples
# sample 9731500 samples
# sample 9732000 samples
# sample 9732500 samples
# sample 9733000 samples
# sample 9733500 samples
# sample 9734000 samples
# sample 9734500 samples
# sample 9735000 samples
# sample 9735500 samples
# sample 9736000 samples
# sample 9736500 samples
# sample 9737000 samples
# sample 9737500 samples
# sample 9738000 samples
# sample 9738500 samples
# sample 9739000 samples
# sample 9739500 samples
# sample 9740000 samples
# sample 9740500 samples
# sample 9741000 samples
# sample 9741500 samples
# sample 9742000 samples
# sample 9742500 samples
# sample 9743000 samples
# sample 9743500 samples
# sample 9744000 samples
# sample 9744500 samples
# sample 9745000 samples
# sample 9745500 samples
# sample 9746000 samples
# sample 9746500 samples
# sample 9747000 samples
# sample 9747500 samples
# sample 9748000 samples
# sample 9748500 samples
# sample 9749000 samples
# sample 9749500 samples
# sample 9750000 samples
# sample 9750500 samples
# sample 9751000 samples
# sample 9751500 samples
# sample 9752000 samples
# sample 9752500 samples
# sample 9753000 samples
# sample 9753500 samples
# sample 9754000 samples
# sample 9754500 samples
# sample 9755000 samples
# sample 9755500 samples
# sample 9756000 samples
# sample 9756500 samples
# sample 9757000 samples
# sample 9757500 samples
# sample 9758000 samples
# sample 9758500 samples
# sample 9759000 samples
# sample 9759500 samples
# sample 9760000 samples
# sample 9760500 samples
# sample 9761000 samples
# sample 9761500 samples
# sample 9762000 samples
# sample 9762500 samples
# sample 9763000 samples
# sample 9763500 samples
# sample 9764000 samples
# sample 9764500 samples
# sample 9765000 samples
# sample 9765500 samples
# sample 9766000 samples
# sample 9766500 samples
# sample 9767000 samples
# sample 9767500 samples
# sample 9768000 samples
# sample 9768500 samples
# sample 9769000 samples
# sample 9769500 samples
# sample 9770000 samples
# sample 9770500 samples
# sample 9771000 samples
# sample 9771500 samples
# sample 9772000 samples
# sample 9772500 samples
# sample 9773000 samples
# sample 9773500 samples
# sample 9774000 samples
# sample 9774500 samples
# sample 9775000 samples
# sample 9775500 samples
# sample 9776000 samples
# sample 9776500 samples
# sample 9777000 samples
# sample 9777500 samples
# sample 9778000 samples
# sample 9778500 samples
# sample 9779000 samples
# sample 9779500 samples
# sample 9780000 samples
# sample 9780500 samples
# sample 9781000 samples
# sample 9781500 samples
# sample 9782000 samples
# sample 9782500 samples
# sample 9783000 samples
# sample 9783500 samples
# sample 9784000 samples
# sample 9784500 samples
# sample 9785000 samples
# sample 9785500 samples
# sample 9786000 samples
# sample 9786500 samples
# sample 9787000 samples
# sample 9787500 samples
# sample 9788000 samples
# sample 9788500 samples
# sample 9789000 samples
# sample 9789500 samples
# sample 9790000 samples
# sample 9790500 samples
# sample 9791000 samples
# sample 9791500 samples
# sample 9792000 samples
# sample 9792500 samples
# sample 9793000 samples
# sample 9793500 samples
# sample 9794000 samples
# sample 9794500 samples
# sample 9795000 samples
# sample 9795500 samples
# sample 9796000 samples
# sample 9796500 samples
# sample 9797000 samples
# sample 9797500 samples
# sample 9798000 samples
# sample 9798500 samples
# sample 9799000 samples
# sample 9799500 samples
# sample 9800000 samples
# sample 9800500 samples
# sample 9801000 samples
# sample 9801500 samples
# sample 9802000 samples
# sample 9802500 samples
# sample 9803000 samples
# sample 9803500 samples
# sample 9804000 samples
# sample 9804500 samples
# sample 9805000 samples
# sample 9805500 samples
# sample 9806000 samples
# sample 9806500 samples
# sample 9807000 samples
# sample 9807500 samples
# sample 9808000 samples
# sample 9808500 samples
# sample 9809000 samples
# sample 9809500 samples
# sample 9810000 samples
# sample 9810500 samples
# sample 9811000 samples
# sample 9811500 samples
# sample 9812000 samples
# sample 9812500 samples
# sample 9813000 samples
# sample 9813500 samples
# sample 9814000 samples
# sample 9814500 samples
# sample 9815000 samples
# sample 9815500 samples
# sample 9816000 samples
# sample 9816500 samples
# sample 9817000 samples
# sample 9817500 samples
# sample 9818000 samples
# sample 9818500 samples
# sample 9819000 samples
# sample 9819500 samples
# sample 9820000 samples
# sample 9820500 samples
# sample 9821000 samples
# sample 9821500 samples
# sample 9822000 samples
# sample 9822500 samples
# sample 9823000 samples
# sample 9823500 samples
# sample 9824000 samples
# sample 9824500 samples
# sample 9825000 samples
# sample 9825500 samples
# sample 9826000 samples
# sample 9826500 samples
# sample 9827000 samples
# sample 9827500 samples
# sample 9828000 samples
# sample 9828500 samples
# sample 9829000 samples
# sample 9829500 samples
# sample 9830000 samples
# sample 9830500 samples
# sample 9831000 samples
# sample 9831500 samples
# sample 9832000 samples
# sample 9832500 samples
# sample 9833000 samples
# sample 9833500 samples
# sample 9834000 samples
# sample 9834500 samples
# sample 9835000 samples
# sample 9835500 samples
# sample 9836000 samples
# sample 9836500 samples
# sample 9837000 samples
# sample 9837500 samples
# sample 9838000 samples
# sample 9838500 samples
# sample 9839000 samples
# sample 9839500 samples
# sample 9840000 samples
# sample 9840500 samples
# sample 9841000 samples
# sample 9841500 samples
# sample 9842000 samples
# sample 9842500 samples
# sample 9843000 samples
# sample 9843500 samples
# sample 9844000 samples
# sample 9844500 samples
# sample 9845000 samples
# sample 9845500 samples
# sample 9846000 samples
# sample 9846500 samples
# sample 9847000 samples
# sample 9847500 samples
# sample 9848000 samples
# sample 9848500 samples
# sample 9849000 samples
# sample 9849500 samples
# sample 9850000 samples
# sample 9850500 samples
# sample 9851000 samples
# sample 9851500 samples
# sample 9852000 samples
# sample 9852500 samples
# sample 9853000 samples
# sample 9853500 samples
# sample 9854000 samples
# sample 9854500 samples
# sample 9855000 samples
# sample 9855500 samples
# sample 9856000 samples
# sample 9856500 samples
# sample 9857000 samples
# sample 9857500 samples
# sample 9858000 samples
# sample 9858500 samples
# sample 9859000 samples
# sample 9859500 samples
# sample 9860000 samples
# sample 9860500 samples
# sample 9861000 samples
# sample 9861500 samples
# sample 9862000 samples
# sample 9862500 samples
# sample 9863000 samples
# sample 9863500 samples
# sample 9864000 samples
# sample 9864500 samples
# sample 9865000 samples
# sample 9865500 samples
# sample 9866000 samples
# sample 9866500 samples
# sample 9867000 samples
# sample 9867500 samples
# sample 9868000 samples
# sample 9868500 samples
# sample 9869000 samples
# sample 9869500 samples
# sample 9870000 samples
# sample 9870500 samples
# sample 9871000 samples
# sample 9871500 samples
# sample 9872000 samples
# sample 9872500 samples
# sample 9873000 samples
# sample 9873500 samples
# sample 9874000 samples
# sample 9874500 samples
# sample 9875000 samples
# sample 9875500 samples
# sample 9876000 samples
# sample 9876500 samples
# sample 9877000 samples
# sample 9877500 samples
# sample 9878000 samples
# sample 9878500 samples
# sample 9879000 samples
# sample 9879500 samples
# sample 9880000 samples
# sample 9880500 samples
# sample 9881000 samples
# sample 9881500 samples
# sample 9882000 samples
# sample 9882500 samples
# sample 9883000 samples
# sample 9883500 samples
# sample 9884000 samples
# sample 9884500 samples
# sample 9885000 samples
# sample 9885500 samples
# sample 9886000 samples
# sample 9886500 samples
# sample 9887000 samples
# sample 9887500 samples
# sample 9888000 samples
# sample 9888500 samples
# sample 9889000 samples
# sample 9889500 samples
# sample 9890000 samples
# sample 9890500 samples
# sample 9891000 samples
# sample 9891500 samples
# sample 9892000 samples
# sample 9892500 samples
# sample 9893000 samples
# sample 9893500 samples
# sample 9894000 samples
# sample 9894500 samples
# sample 9895000 samples
# sample 9895500 samples
# sample 9896000 samples
# sample 9896500 samples
# sample 9897000 samples
# sample 9897500 samples
# sample 9898000 samples
# sample 9898500 samples
# sample 9899000 samples
# sample 9899500 samples
# sample 9900000 samples
# sample 9900500 samples
# sample 9901000 samples
# sample 9901500 samples
# sample 9902000 samples
# sample 9902500 samples
# sample 9903000 samples
# sample 9903500 samples
# sample 9904000 samples
# sample 9904500 samples
# sample 9905000 samples
# sample 9905500 samples
# sample 9906000 samples
# sample 9906500 samples
# sample 9907000 samples
# sample 9907500 samples
# sample 9908000 samples
# sample 9908500 samples
# sample 9909000 samples
# sample 9909500 samples
# sample 9910000 samples
# sample 9910500 samples
# sample 9911000 samples
# sample 9911500 samples
# sample 9912000 samples
# sample 9912500 samples
# sample 9913000 samples
# sample 9913500 samples
# sample 9914000 samples
# sample 9914500 samples
# sample 9915000 samples
# sample 9915500 samples
# sample 9916000 samples
# sample 9916500 samples
# sample 9917000 samples
# sample 9917500 samples
# sample 9918000 samples
# sample 9918500 samples
# sample 9919000 samples
# sample 9919500 samples
# sample 9920000 samples
# sample 9920500 samples
# sample 9921000 samples
# sample 9921500 samples
# sample 9922000 samples
# sample 9922500 samples
# sample 9923000 samples
# sample 9923500 samples
# sample 9924000 samples
# sample 9924500 samples
# sample 9925000 samples
# sample 9925500 samples
# sample 9926000 samples
# sample 9926500 samples
# sample 9927000 samples
# sample 9927500 samples
# sample 9928000 samples
# sample 9928500 samples
# sample 9929000 samples
# sample 9929500 samples
# sample 9930000 samples
# sample 9930500 samples
# sample 9931000 samples
# sample 9931500 samples
# sample 9932000 samples
# sample 9932500 samples
# sample 9933000 samples
# sample 9933500 samples
# sample 9934000 samples
# sample 9934500 samples
# sample 9935000 samples
# sample 9935500 samples
# sample 9936000 samples
# sample 9936500 samples
# sample 9937000 samples
# sample 9937500 samples
# sample 9938000 samples
# sample 9938500 samples
# sample 9939000 samples
# sample 9939500 samples
# sample 9940000 samples
# sample 9940500 samples
# sample 9941000 samples
# sample 9941500 samples
# sample 9942000 samples
# sample 9942500 samples
# sample 9943000 samples
# sample 9943500 samples
# sample 9944000 samples
# sample 9944500 samples
# sample 9945000 samples
# sample 9945500 samples
# sample 9946000 samples
# sample 9946500 samples
# sample 9947000 samples
# sample 9947500 samples
# sample 9948000 samples
# sample 9948500 samples
# sample 9949000 samples
# sample 9949500 samples
# sample 9950000 samples
# sample 9950500 samples
# sample 9951000 samples
# sample 9951500 samples
# sample 9952000 samples
# sample 9952500 samples
# sample 9953000 samples
# sample 9953500 samples
# sample 9954000 samples
# sample 9954500 samples
# sample 9955000 samples
# sample 9955500 samples
# sample 9956000 samples
# sample 9956500 samples
# sample 9957000 samples
# sample 9957500 samples
# sample 9958000 samples
# sample 9958500 samples
# sample 9959000 samples
# sample 9959500 samples
# sample 9960000 samples
# sample 9960500 samples
# sample 9961000 samples
# sample 9961500 samples
# sample 9962000 samples
# sample 9962500 samples
# sample 9963000 samples
# sample 9963500 samples
# sample 9964000 samples
# sample 9964500 samples
# sample 9965000 samples
# sample 9965500 samples
# sample 9966000 samples
# sample 9966500 samples
# sample 9967000 samples
# sample 9967500 samples
# sample 9968000 samples
# sample 9968500 samples
# sample 9969000 samples
# sample 9969500 samples
# sample 9970000 samples
# sample 9970500 samples
# sample 9971000 samples
# sample 9971500 samples
# sample 9972000 samples
# sample 9972500 samples
# sample 9973000 samples
# sample 9973500 samples
# sample 9974000 samples
# sample 9974500 samples
# sample 9975000 samples
# sample 9975500 samples
# sample 9976000 samples
# sample 9976500 samples
# sample 9977000 samples
# sample 9977500 samples
# sample 9978000 samples
# sample 9978500 samples
# sample 9979000 samples
# sample 9979500 samples
# sample 9980000 samples
# sample 9980500 samples
# sample 9981000 samples
# sample 9981500 samples
# sample 9982000 samples
# sample 9982500 samples
# sample 9983000 samples
# sample 9983500 samples
# sample 9984000 samples
# sample 9984500 samples
# sample 9985000 samples
# sample 9985500 samples
# sample 9986000 samples
# sample 9986500 samples
# sample 9987000 samples
# sample 9987500 samples
# sample 9988000 samples
# sample 9988500 samples
# sample 9989000 samples
# sample 9989500 samples
# sample 9990000 samples
# sample 9990500 samples
# sample 9991000 samples
# sample 9991500 samples
# sample 9992000 samples
# sample 9992500 samples
# sample 9993000 samples
# sample 9993500 samples
# sample 9994000 samples
# sample 9994500 samples
# sample 9995000 samples
# sample 9995500 samples
# sample 9996000 samples
# sample 9996500 samples
# sample 9997000 samples
# sample 9997500 samples
# sample 9998000 samples
# sample 9998500 samples
# sample 9999000 samples
# sample 9999500 samples
# 32

# %%
pickle_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/in_test.pkl"
sample_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/in_test_samples_"+str(segment_size)+".json"
n_samples = testing_samples

sample_single_segments(pickle_path,sample_path,segment_size,n_samples)
gc.collect()
# Out:
# 893 utterances
# sample 0 samples
# sample 500 samples
# sample 1000 samples
# sample 1500 samples
# sample 2000 samples
# sample 2500 samples
# sample 3000 samples
# sample 3500 samples
# sample 4000 samples
# sample 4500 samples
# sample 5000 samples
# sample 5500 samples
# sample 6000 samples
# sample 6500 samples
# sample 7000 samples
# sample 7500 samples
# sample 8000 samples
# sample 8500 samples
# sample 9000 samples
# sample 9500 samples
# 32

# %%
pickle_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/out_test.pkl"
sample_path = "/raid/users/ayesilkanat/MSC/adaptive-accent-conversion/setup2/spectrograms/sr_24000_mel_norm_128frame_256mel/out_test_samples_"+str(segment_size)+".json"
n_samples = testing_samples
sample_single_segments(pickle_path,sample_path,segment_size,n_samples)
gc.collect()
# Out:
# 1087 utterances
# sample 0 samples
# sample 500 samples
# sample 1000 samples
# sample 1500 samples
# sample 2000 samples
# sample 2500 samples
# sample 3000 samples
# sample 3500 samples
# sample 4000 samples
# sample 4500 samples
# sample 5000 samples
# sample 5500 samples
# sample 6000 samples
# sample 6500 samples
# sample 7000 samples
# sample 7500 samples
# sample 8000 samples
# sample 8500 samples
# sample 9000 samples
# sample 9500 samples
# 32

# %%
2+2
# Out:
# 4
